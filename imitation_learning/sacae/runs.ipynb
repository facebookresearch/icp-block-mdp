# %%
# Copyright (c) Facebook, Inc. and its affiliates.

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import os
import json
import torch
import graph_utils as gu
import utils
import dmc2gym
from matplotlib import cm
# %matplotlib inline  
np.warnings.filterwarnings('ignore')

# %%
ROOT = '/checkpoint/amyzhang/causRLity'
TASKS = sorted(os.listdir(ROOT))

# %%
# different size encoder architectures
for task in TASKS:
    gu.plot_experiment(
            task,
            '(sac_ae)', # '(sac_states$|0718192.*_sac_states_alr_5|0718195|.*vae)', 
            root=ROOT,
            train=False,
            num_seeds=1,
            value_name='train_episode_reward',
            gen_gap=True)
    plt.show()
# Out:
# bad file: /checkpoint/amyzhang/causRLity/walker_walk/sac_ae/seed_1/eval.log

# %%
for task in TASKS:
    gu.plot_experiment(
            task,
            '(sac_ae)', # '(sac_states$|0718192.*_sac_states_alr_5|0718195|.*vae)', 
            root=ROOT,
            train=True,
            num_seeds=1,
            value_name='episode_reward')
    plt.show()
# Out:
# bad file: /checkpoint/amyzhang/causRLity/walker_walk/sac_ae/seed_1/train.log

# %%
# Out:
#   File "<ipython-input-5-b3c78df7aa70>", line 10
#     n)
#     ^
# SyntaxError: positional argument follows keyword argument
